# %%
import cv2  # Import OpenCV for video processing and drawing
import numpy as np  # Import NumPy for numerical operations
from ultralytics import YOLO  # Import YOLO from Ultralytics for object detection
import base64  # Import base64 for encoding images to send to OpenAI
import os  # Import os for file operations (e.g., checking if file exists)
import time  # Import time for timing operations (e.g., frame intervals)
import threading  # Import threading for running tasks in parallel (e.g., frame reading)
from queue import Queue  # Import Queue for thread-safe frame buffering
import asyncio  # Import asyncio for asynchronous OpenAI API calls
import aiohttp  # Import aiohttp for making async HTTP requests to OpenAI
import cvzone  # Import cvzone for enhanced text rendering on frames

# Initialize OpenAI client (for compatibility, but we'll use aiohttp for async calls)
from openai import OpenAI  # Import OpenAI library for API client initialization
client = OpenAI(  # Create an OpenAI client instance
    base_url="https://openrouter.ai/api/v1",  # Set the base URL to OpenRouter's API endpoint
    api_key="",  # Set your OpenRouter API key (replace with your actual key)
)

class CarAccidentDetectionProcessor:  # Define the class for accident detection processing
    def __init__(self, video_file, yolo_model_path="yolo12s.pt", output_video_file="output_video.mp4"):  # Constructor with video file and model paths
        """Initialize car accident detection processor."""
        try:  # Start a try block to handle potential errors
            self.yolo_model = YOLO(yolo_model_path)  # Load the YOLO model from the specified path
            self.names = self.yolo_model.names  # Get class names (e.g., "car", "accident") from the model
        except Exception as e:  # Catch any errors during model loading
            raise RuntimeError(f"Error loading YOLO model: {e}")  # Raise an error with details if loading fails

        self.cap = cv2.VideoCapture(video_file)  # Open the input video file
        if not self.cap.isOpened():  # Check if the video file opened successfully
            raise FileNotFoundError("Error: Could not open video file.")  # Raise an error if video can't be opened

        self.frame_width = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # Get the video's frame width
        self.frame_height = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT))  # Get the video's frame height
        self.fps = int(self.cap.get(cv2.CAP_PROP_FPS))  # Get the video's frames per second (FPS)

        self.output_video_file = output_video_file  # Store the output video file path
        self.video_writer = cv2.VideoWriter(  # Initialize the video writer to save processed video
            self.output_video_file,  # Output file path
            cv2.VideoWriter_fourcc(*'mp4v'),  # Use MP4V codec for .mp4 files
            self.fps,  # Set the FPS for the output video
            (self.frame_width, self.frame_height)  # Set the frame size for the output video
        )

        self.current_date = time.strftime("%Y-%m-%d_%H-%M-%S")  # Get current date and time for unique folder name
        self.images_folder = os.path.join("sent_images", f"images_{self.current_date}")  # Define folder path
        if not os.path.exists(self.images_folder):  # Check if folder doesn't exist
            os.makedirs(self.images_folder)  # Create the folder
        self.image_counter = 0  # Counter for unique image filenames

        self.output_filename = f"accident_data_{self.current_date}.txt"  # Define the output text file name
        self.frame_counter = 0  # Initialize a counter for frames processed
        self.last_frame_sent_time = 0  # Track the last time a frame was sent to OpenAI
        self.frame_queue = Queue(maxsize=10)  # Create a queue for video frame reading (max 10 frames)
        self.analysis_queue = []  # List to queue frames for OpenAI analysis
        self.lock = threading.Lock()  # Create a lock for thread-safe queue access
        self.stop_event = threading.Event()  # Event to signal threads to stop
        self.buffer = []  # Buffer to store text data before writing to file
        self.latest_response = ""  # Store the latest OpenAI response for display

        if not os.path.exists(self.output_filename):  # Check if the output text file doesn't exist
            with open(self.output_filename, "w", encoding="utf-8") as file:  # Create and open the file for writing
                file.write("Timestamp | Track ID | Accident Severity | Vehicles Involved | Location Details | Reason\n")  # Write header
                file.write("-" * 100 + "\n")  # Write a separator line

    async def analyze_frame_with_openai(self, frame, track_id, session):  # Async method to analyze frames with OpenAI
        """Analyze frame asynchronously using OpenAI via OpenRouter.ai with an improved prompt."""
        try:  # Start a try block to handle API call errors
            frame_small = cv2.resize(frame, (320, 240))  # Resize frame to 320x240 for faster processing
            _, img_buffer = cv2.imencode(".jpg", frame_small, [int(cv2.IMWRITE_JPEG_QUALITY), 70])  # Encode frame to JPG with 70% quality
            base64_image = base64.b64encode(img_buffer).decode("utf-8")  # Convert encoded image to base64 string

            prompt = """
                Analyze the image, a frame from a road surveillance video, to detect and assess any car accident. Focus on clear visual indicators such as:
                
                - **Vehicle Damage**: Dents, broken parts, open hoods, or misalignment.
                - **Unusual Vehicle Positions**: Off-road, collisions, or abnormal angles.
                - **Debris & Skid Marks**: Road obstacles, scattered parts, or visible tire marks.
                - **Traffic Disruption**: Stalled vehicles, congestion, or people gathering.
                - **Weather Impact**: Wet roads or low visibility affecting conditions.
                
                ### Output Format:
                Provide a structured table summarizing the findings strictly based on visible evidence:
                
                | Accident Severity (Details) | Vehicles Involved | Location Type | Likely Cause               |
                |------------------|-------------------|--------------|----------------------------|
                | Medium / High | Number of affected vehicles | (e.g., intersection, village road) | (e.g., collision, skidding, unclear) |
                
                ### Severity Levels:
                - **Medium**: Minor damage, clustering of people/cars, open car hood , Unusual Vehicle Positions, Unusual people Positions , collisions.
                - **High**: Severe damage, emergency response, road blockage.
                
                Stick to observed evidence and avoid speculation.
                """
 # Define the detailed prompt for OpenAI to detect accidents accurately
            api_key = ""  # API key (replace with your actual key)
            async with session.post(  # Make an async POST request to OpenRouter API
                "https://openrouter.ai/api/v1/chat/completions",  # API endpoint
                headers={"Authorization": f"Bearer {api_key}"},  # Authorization header with API key
                json={  # JSON payload for the request
                    "model": "google/gemini-2.0-pro-exp-02-05:free",  # Specify the model to use
                    "messages": [  # List of messages for the chat completion
                        {
                            "role": "user",  # User role for the message
                            "content": [  # Content array with text and image
                                {"type": "text", "text": prompt},  # Text prompt
                                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}}  # Image data
                            ]
                        }
                    ]
                }
            ) as response:  # Store the response
                result = await response.json()  # Parse the response as JSON
                if "choices" in result and result["choices"]:  # Check if response has valid choices
                    response_text = result["choices"][0]["message"]["content"].strip()  # Extract the response text
                    print("Response", response_text)  # Print the response for debugging
                    return response_text  # Return the response
                print("❌ Invalid response from OpenAI API.")  # Log invalid response
                return "Error: Invalid response from OpenAI API."  # Return error message
        except Exception as e:  # Catch any errors during API call
            print(f"❌ Error invoking OpenAI model: {e}")  # Log the error
            return "Error processing image."  # Return error message

    def process_frame_in_thread(self):  # Method to process frames in a separate thread
        """Process frames from the analysis queue asynchronously."""
        async def run_analysis():  # Define async function for analysis
            async with aiohttp.ClientSession() as session:  # Create an async HTTP session
                while not self.stop_event.is_set():  # Loop until stop event is triggered
                    if self.analysis_queue:  # Check if there are frames to analyze
                        with self.lock:  # Lock the queue for thread-safe access
                            frame, timestamp, track_id = self.analysis_queue.pop(0)  # Get the next frame from queue
                        response_content = await self.analyze_frame_with_openai(frame, track_id, session)  # Analyze frame
                        extracted_data = response_content.split("\n")[2:]  # Extract data rows, skipping header
                        if extracted_data:  # Check if there’s data to process
                            for row in extracted_data:  # Loop through each data row
                                if "--------------" in row or not row.strip():  # Skip separator or empty lines
                                    continue
                                values = [col.strip() for col in row.split("|")[1:-1]]  # Parse row into values
                                if len(values) == 4:  # Ensure 4 columns (severity, vehicles, location, reason)
                                    severity, vehicles, location, reason = values  # Unpack values
                                    self.buffer.append(f"{timestamp} | {track_id} | {severity} | {vehicles} | {location} | {reason}\n")  # Add to buffer
                                    self.latest_response = f"Severity: {severity}\nVehicles: {vehicles}\nLocation: {location}\nReason: {reason}"  # Update latest response
                                    print(f"✅ Accident detected: Track ID={track_id}, Severity={severity}, Reason={reason}")  # Log detection
                            if len(self.buffer) >= 5:  # Check if buffer has 5 or more entries
                                with open(self.output_filename, "a", encoding="utf-8") as file:  # Open file in append mode
                                    file.writelines(self.buffer)  # Write buffer to file
                                self.buffer = []  # Clear buffer after writing
                    else:  # If no frames in queue
                        await asyncio.sleep(0.1)  # Sleep briefly to avoid busy-waiting

        asyncio.run(run_analysis())  # Run the async analysis function

    def process_frame(self, frame, track_id):  # Method to queue frames for analysis
        """Add frame to analysis queue every 2 seconds and save it."""
        current_time = time.time()  # Get current time
        if current_time - self.last_frame_sent_time >= 1:  # Check if 2 seconds have passed since last send
            self.last_frame_sent_time = current_time  # Update last sent time
            timestamp = time.strftime("%Y-%m-%d %H:%M:%S")  # Get current timestamp
            with self.lock:  # Lock the queue for thread-safe access
                if len(self.analysis_queue) < 10:  # Check if queue has space (max 10)
                    # Save the frame to the images folder
                    self.image_counter += 1
                    image_filename = os.path.join(self.images_folder, f"frame_{self.image_counter:04d}.jpg")
                    cv2.imwrite(image_filename, frame)  # Save the original frame
                    self.analysis_queue.append((frame, timestamp, track_id))  # Add frame to analysis queue

    def process_video_frame(self, frame):  # Method to process frames with YOLO
        """Process video frame with YOLO and display class and ID in top-left with style."""
        frame_resized = cv2.resize(frame, (640, 480))  # Resize frame for faster YOLO inference
        results = self.yolo_model.track(frame_resized, persist=True)  # Run YOLO tracking on resized frame

        if results and results[0].boxes is not None:  # Check if detection results exist
            boxes = results[0].boxes.xyxy.int().cpu().tolist()  # Get bounding box coordinates
            class_ids = results[0].boxes.cls.int().cpu().tolist()  # Get class IDs
            track_ids = results[0].boxes.id.int().cpu().tolist() if results[0].boxes.id is not None else [-1] * len(boxes)  # Get track IDs or default to -1

            scale_x, scale_y = self.frame_width / 640, self.frame_height / 480  # Calculate scaling factors for original resolution
            for box, class_id, track_id in zip(boxes, class_ids, track_ids):  # Loop through detections
                x1, y1, x2, y2 = map(int, [box[0] * scale_x, box[1] * scale_y, box[2] * scale_x, box[3] * scale_y])  # Scale coordinates to original frame
                class_name = self.names[class_id]  # Get class name from ID

                if class_name == "car" or class_name == "accident":  # Check if detected object is a car or accident
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)  # Draw red bounding box
                    label = f"{class_name} ID: {track_id}"  # Create label with class and ID
                    cvzone.putTextRect(  # Add styled text above bounding box
                        frame, 
                        label, 
                        (x1, y1 - 10),  # Position at top-left, slightly above box
                        scale=1,  # Medium font size
                        thickness=2,  # Text thickness
                        colorT=(0, 0, 0),  # Black text
                        colorR=(173, 216, 230),  # Light blue background
                        offset=5  # Padding around text
                    )
                    self.process_frame(frame, track_id)  # Queue frame for OpenAI analysis

        return frame  # Return processed frame

    def post_process_frame(self, frame):  # Method to add alerts and OpenAI response
        """Add alerts and OpenAI response to the frame."""
        with open(self.output_filename, "r", encoding="utf-8") as file:  # Open the text file for reading
            lines = file.readlines()  # Read all lines from file

        for line in lines[2:]:  # Loop through lines, skipping header and separator
            if "|" in line and "Accident Severity (Details)" not in line:  # Filter out header-like rows
                parts = [part.strip() for part in line.split("|")]  # Split and strip line into parts
                if len(parts) >= 3:  # Ensure enough columns exist
                    severity = parts[2].lower()  # Get severity column and convert to lowercase
                    if "medium" in severity or "high" in severity:  # Check for medium or high severity
                        cv2.putText(frame, "ALERT: Accident Detected!", (10, 50),  # Add alert text
                                  cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)  # Bold red text
                        break  # Exit loop after adding alert

        if self.latest_response:  # Check if there’s a response to display
            y_pos = self.frame_height - 120  # Start position 120 pixels from bottom
            for line in self.latest_response.split("\n"):  # Loop through response lines
                cvzone.putTextRect(  # Add each line with styled rectangle
                    frame, 
                    line, 
                    (10, y_pos),  # Position at current y-coordinate
                    scale=0.8,  # Smaller font size
                    thickness=1,  # Text thickness
                    colorT=(255, 255, 255),  # White text
                    colorR=(50, 50, 50),  # Dark gray background
                    offset=5  # Padding around text
                )
                y_pos += 30  # Move up 30 pixels for next line

        return frame  # Return processed frame

    def read_frames(self):  # Method to read frames in a separate thread
        """Read frames in a separate thread."""
        while self.cap.isOpened():  # Loop while video is open
            ret, frame = self.cap.read()  # Read next frame
            if not ret:  # Check if frame reading failed (end of video)
                break  # Exit loop if no more frames
            self.frame_queue.put(frame)  # Add frame to queue
        self.frame_queue.put(None)  # Add None to signal end of video

    def start_processing(self):  # Main method to start video processing
        """Start video processing with optimizations."""
        threading.Thread(target=self.read_frames, daemon=True).start()  # Start frame reading thread
        threading.Thread(target=self.process_frame_in_thread, daemon=True).start()  # Start analysis thread

        while True:  # Main processing loop
            frame = self.frame_queue.get()  # Get next frame from queue
            if frame is None:  # Check if end of video (None received)
                break  # Exit loop if no more frames
            self.frame_counter += 1  # Increment frame counter
            if self.frame_counter % 3 == 0:  # Process every 3rd frame for efficiency
                processed_frame = self.process_video_frame(frame)  # Process frame with YOLO
                processed_frame = self.post_process_frame(processed_frame)  # Add alerts and response
                self.video_writer.write(processed_frame)  # Write frame to output video
                cv2.imshow("Car Accident Detection", processed_frame)  # Display processed frame
                if cv2.waitKey(1) & 0xFF == ord("q"):  # Check for 'q' key to quit
                    break  # Exit loop if 'q' pressed

        self.stop_event.set()  # Signal threads to stop
        self.cap.release()  # Release video capture resource
        self.video_writer.release()  # Release video writer resource
        cv2.destroyAllWindows()  # Close all OpenCV windows
        if self.buffer:  # Check if buffer has remaining data
            with open(self.output_filename, "a", encoding="utf-8") as file:  # Open file in append mode
                file.writelines(self.buffer)  # Write remaining buffer to file
        print(f"✅ Processing completed. Output video saved to {self.output_video_file}")  # Log completion

if __name__ == "__main__":  # Entry point for script execution
    video_file = "b.mp4"  # Specify input video file (replace with your file)
    output_video_file = "output_video.mp4"  # Specify output video file name
    processor = CarAccidentDetectionProcessor(video_file, output_video_file=output_video_file)  # Create processor instance
    processor.start_processing()  # Start the processing
# Out:
# 0: 480x640 1 car, 116.6ms
# Speed: 11.0ms preprocess, 116.6ms inference, 336.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 26.9ms
# Speed: 2.6ms preprocess, 26.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 25.0ms
# Speed: 2.3ms preprocess, 25.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 25.7ms
# Speed: 3.7ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 24.1ms
# Speed: 2.6ms preprocess, 24.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 22.3ms
# Speed: 2.1ms preprocess, 22.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 2.6ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 1.7ms preprocess, 21.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 24.1ms
# Speed: 1.9ms preprocess, 24.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 30.6ms
# Speed: 3.5ms preprocess, 30.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 28.7ms
# Speed: 2.2ms preprocess, 28.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 31.5ms
# Speed: 1.8ms preprocess, 31.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 31.8ms
# Speed: 1.4ms preprocess, 31.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 2.5ms preprocess, 21.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.5ms
# Speed: 1.9ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 25.6ms
# Speed: 3.1ms preprocess, 25.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.4ms
# Speed: 1.5ms preprocess, 21.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.0ms
# Speed: 2.5ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 27.8ms
# Speed: 1.6ms preprocess, 27.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.5ms
# Speed: 2.3ms preprocess, 20.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 21.7ms
# Speed: 1.7ms preprocess, 21.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 20.6ms
# Speed: 1.5ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 24.4ms
# Speed: 1.8ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 26.2ms
# Speed: 1.8ms preprocess, 26.2ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1
ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 22.5ms
# Speed: 1.9ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 23.8ms
# Speed: 1.7ms preprocess, 23.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.2ms
# Speed: 1.1ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.4ms
# Speed: 1.7ms preprocess, 22.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.3ms
# Speed: 1.9ms preprocess, 22.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.3ms
# Speed: 1.2ms preprocess, 22.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 24.9ms
# Speed: 1.6ms preprocess, 24.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 24.2ms
# Speed: 4.7ms preprocess, 24.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 21.7ms
# Speed: 1.9ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 28.6ms
# Speed: 2.5ms preprocess, 28.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 26.3ms
# Speed: 1.1ms preprocess, 26.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 28.2ms
# Speed: 1.5ms preprocess, 28.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 35.3ms
# Speed: 1.9ms preprocess, 35.3ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 21.9ms
# Speed: 2.6ms preprocess, 21.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 20.9ms
# Speed: 1.1ms preprocess, 20.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 20.7ms
# Speed: 1.3ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 39.3ms
# Speed: 5.0ms preprocess, 39.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 42.5ms
# Speed: 6.1ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 22.5ms
# Speed: 1.4ms preprocess, 22.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 20.7ms
# Speed: 1.7ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 21.0ms
# Speed: 1.7ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 28.8ms
# Speed: 1.6ms preprocess, 28.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 27.5ms
# Speed: 3.8ms preprocess, 27.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 23.3ms
# Speed: 1.5ms preprocess, 23.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 23.9ms
# Speed: 2.6ms preprocess, 23.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 cars, 1 truck, 22.5ms
# Speed: 1.6ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 20.8ms
# Speed: 1.4ms preprocess, 20.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars, 1 truck, 20.8ms
# Speed: 1.1ms preprocess, 20.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# Response Here's an analysis of the provided image and a structured table summarizing the findings:
#
# **Image Analysis:**
#
# The image shows a flooded road with a white car (identified as "car ID: 1") driving through. The road appears to be in a rural or semi-rural area, with houses and trees visible in the background. The weather is clearly wet, with significant water accumulation on the road surface.
#
# **Table:**
#
# | Accident Severity (Details) | Vehicles Involved | Location Type | Likely Cause               |
# |-----------------------------|-------------------|----------------|----------------------------|
# | None Visible              | 1 (Identified)    | Village Road   | Flooding/Unclear          |
#
# **Explanation:**
#
# *   **Accident Severity:** Based solely on the image, there's no visible evidence of an accident. No damage, unusual positioning, debris, or traffic disruption is apparent.
# *	Medium is not suit because, there no visible damage, and no disruption is apparent.
# *    High is not suit because,there is no emergency response is apparent.
# *   **Vehicles Involved:** Only one vehicle is clearly identified and highlighted in the image.
# *   **Location Type:** The presence of houses and the general environment suggest a village or rural road.
# *   **Likely Cause:** The most apparent issue is the significant flooding of the road, which in and of itself poses a hazard, although no accident is directly seen. The cause of any potential incident (not visible) is unclear, but the water could contribute to hydroplaning or reduced visibility.
#
# **Important Note:**
# The detection system is identifying the vehicle so the vehicle is not stalled.
# ✅ Accident detected: Track ID=1, Severity=Accident Severity (Details), Reason=Likely Cause
# ✅ Accident detected: Track ID=1, Severity=None Visible, Reason=Flooding/Unclear
# 0: 480x640 4 cars, 2 trucks, 20.7ms
# Speed: 1.7ms preprocess, 20.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 cars,
ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Response Here's an analysis of the provided image and the assessment table:
#
# **Analysis:**
#
# The image shows a road scene, likely in a rural or village area ("Усть-Кут" is visible in the bottom right, suggesting a location in Russia). The road appears wet, indicating recent rain. A white car ("car ID: 1") is positioned in the middle of what seems to be an intersection or a junction with a smaller road.
# A truck and a trailer a visible behind car ID:1.
#
# **Assessment Table:**
#
# | Accident Severity (Details) | Vehicles Involved | Location Type | Likely Cause               |
# |-----------------------------|-------------------|--------------|----------------------------|
# | Medium                      |Possibly 2: Car    |  T-junction/Intersection  of main road and side-road          |   Unclear, possibly failed Right of Way          |
#
# **Reasoning:**
#
# *   **Accident Severity (Medium):** While no obvious major damage is evident, the car is in a unusual position. The truck can also possibly be affected. These are both indications for the medium severity level.
# *   **Vehicles Involved:** One vehicle is clearly identified ("car ID: 1").
# *  **Location Type: T-junction/Intersection.**
# *   **Likely Cause (Unclear, possibly failed right of way):** The wet conditions might have contributed. It isn't possible to determine the full cause without more context or video frames preceding this one.
#
# It is importent to note that the cause is unclear, therefore added a possibly reason that can fit the scenario.
# ✅ Accident detected: Track ID=1, Severity=Accident Severity (Details), Reason=Likely Cause
# ✅ Accident detected: Track ID=1, Severity=Medium, Reason=Unclear, possibly failed Right of Way
# 0: 480x640 1 person, 5 cars, 1 truck, 27.7ms
# Speed: 2.2ms preprocess, 27.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 19.8ms
# Speed: 1.1ms preprocess, 19.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 22.4ms
# Speed: 2.6ms preprocess, 22.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 19.9ms
# Speed: 1.1ms preprocess, 19.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 26.1ms
# Speed: 1.0ms preprocess, 26.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 24.5ms
# Speed: 2.2ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 26.1ms
# Speed: 1.3ms preprocess, 26.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 32.0ms
# Speed: 1.2ms preprocess, 32.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 42.8ms
# Speed: 2.1ms preprocess, 42.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 25.7ms
# Speed: 2.0ms preprocess, 25.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 cars, 1 truck, 23.6ms
# Speed: 1.5ms preprocess, 23.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 21.7ms
# Speed: 1.4ms preprocess, 21.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 27.4ms
# Speed: 2.2ms preprocess, 27.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 30.6ms
# Speed: 1.7ms preprocess, 30.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 21.5ms
# Speed: 1.5ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 2 trucks, 23.6ms
# Speed: 1.6ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 2 trucks, 23.7ms
# Speed: 1.3ms preprocess, 23.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 2 trucks, 21.8ms
# Speed: 1.5ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cars, 2 trucks, 21.6ms
# Speed: 2.6ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 cars, 1 truck, 40.1ms
# Speed: 1.6ms preprocess, 40.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person,
ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 6 cars, 3 trucks, 22.2ms
# Speed: 2.3ms preprocess, 22.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 7 cars, 2 trucks, 22.2ms
# Speed: 1.6ms preprocess, 22.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 1 truck, 22.5ms
# Speed: 2.1ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 7 cars, 1 truck, 22.6ms
# Speed: 2.6ms preprocess, 22.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 6 cars, 2 trucks, 23.5ms
# Speed: 2.5ms preprocess, 23.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 6 cars, 2 trucks, 22.5ms
# Speed: 2.3ms preprocess, 22.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 1 truck, 22.8ms
# Speed: 1.4ms preprocess, 22.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 1 truck, 22.7ms
# Speed: 2.4ms preprocess, 22.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 23.0ms
# Speed: 2.9ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 1 truck, 34.5ms
# Speed: 2.1ms preprocess, 34.5ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 22.4ms
# Speed: 1.8ms preprocess, 22.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 1 truck, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 6 cars, 2 trucks, 23.3ms
# Speed: 2.6ms preprocess, 23.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 1 truck, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 1 truck, 25.8ms
# Speed: 1.1ms preprocess, 25.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 26.8ms
# Speed: 2.4ms preprocess, 26.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 30.4ms
# Speed: 1.2ms preprocess, 30.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 23.2ms
# Speed: 1.8ms preprocess, 23.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 1 truck, 23.4ms
# Speed: 1.7ms preprocess, 23.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 26.0ms
# Speed: 2.2ms preprocess, 26.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# Response Here's an analysis of the provided image and a structured table summarizing the findings:
#
# **Analysis:**
#
# The image shows a wet road, likely after rainfall. A single car ("car ID: 1") is detected, driving on what appears to be a main road merging with a smaller side road. There are no other vehicles immediately visible near the detected car, and no signs of immediate collision. There is one vehicle far on the Incoming, With no clear evidence of damage.
#
# **Table:**
#
# | Accident Severity (Details) | Vehicles Involved | Location Type    | Likely Cause               |
# |-----------------------------|-------------------|-------------------|----------------------------|
# | Medium   |        1          | Merging Roads/ T       |       Unclear.Potentially Low visability and wet floor.                     |
#
# **Explanation:**
# *   Severity is set at meduim.
# *   Only the tracked car is confirmed.
# *  Weather Impact:It's clear that is a Rainy day.
#
# **No clear evidence of an accident is visible in this single frame.** More frames or video context would be needed to definitively conclude anything beyond wet and Low visibility conditions.
# ✅ Accident detected: Track ID=1, Severity=Accident Severity (Details), Reason=Likely Cause
# ✅ Accident detected: Track ID=1, Severity=Medium, Reason=Unclear.Potentially Low visability and wet floor.
# 0: 480x640 4 persons, 7 cars, 2 trucks, 25.1ms
# Speed: 2.9ms preprocess, 25.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 2 trucks, 23.6ms
# Speed: 2.6ms preprocess, 23.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 2 trucks, 23.4ms
# Speed: 1.9ms preprocess, 23.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 6 cars, 3 trucks, 25.4ms
# Speed: 1.1ms preprocess, 25.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 2 trucks, 23.6ms
# Speed: 2.1ms preprocess, 23.6ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 3 trucks, 23.9ms
# Speed: 1.9ms preprocess, 23.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 3 trucks, 29.9ms
# Speed: 3.7ms preprocess, 29.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 2 trucks, 26.4ms
# Speed: 1.7ms preprocess, 26.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 7 cars, 4 trucks, 24.8ms
# Speed: 1.6ms preprocess, 24.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 4 trucks, 24.6ms
# Speed: 1.0ms preprocess, 24.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 10 cars, 2 trucks, 24.2ms
# Speed: 1.3ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 9 cars, 24.9ms
# Speed: 1.6ms preprocess, 24.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 9 cars, 1 truck, 24.7ms
# Speed: 2.5ms preprocess, 24.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 9 cars, 2 trucks, 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 9 cars, 1 truck, 24.3ms
# Speed: 2.8ms preprocess, 24.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 1 truck, 39.0ms
# Speed: 1.5ms preprocess, 39.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 3 trucks, 40.2ms
# Speed: 1.3ms preprocess, 40.2ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 2 trucks, 24.7ms
# Speed: 1.9ms preprocess, 24.7ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 3 trucks, 32.1ms
# Speed: 2.4ms preprocess, 32.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 8 cars, 2 trucks, 25.2ms
# Speed: 1.3ms preprocess, 25.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 2 trucks, 24.9ms
# Speed: 1.1ms preprocess, 24.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 3 trucks, 24.8ms
# Speed: 1.5ms preprocess, 24.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 2 trucks, 25.0ms
# Speed: 1.5ms preprocess, 25.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 4 trucks, 25.2ms
# Speed: 2.8ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 7 cars, 4 trucks, 25.2ms
# Speed: 2.9ms preprocess, 25.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 4 trucks, 25.1ms
# ...
# | --------------------------- | ----------------- | ------------- | -------------------------------------------------------------------- |
# | Medium                      | Possibly 2        | T-Junction    | Unclear, possbly Failed Right of Way.                                     |
#
# **Reasoning:**
# The system presents "Severity: Medium" and suggests "Unclear, possibly failed right of Way"
# The medium is because of the cars positioning in the intersection.
# ✅ Accident detected: Track ID=13, Severity=Accident Severity (Details), Reason=Likely Cause
# ✅ Accident detected: Track ID=13, Severity=Medium, Reason=Unclear, possbly Failed Right of Way.
# 0: 480x640 6 persons, 12 cars, 2 trucks, 22.5ms
# Speed: 1.2ms preprocess, 22.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 12 cars, 3 trucks, 22.5ms
# Speed: 2.1ms preprocess, 22.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 12 cars, 3 trucks, 36.5ms
# Speed: 1.6ms preprocess, 36.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 1 truck, 22.4ms
# Speed: 1.7ms preprocess, 22.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 10 cars, 4 trucks, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 4 trucks, 24.0ms
# Speed: 2.1ms preprocess, 24.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 3 trucks, 23.8ms
# Speed: 2.0ms preprocess, 23.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 10 cars, 4 trucks, 23.6ms
# Speed: 1.7ms preprocess, 23.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 3 trucks, 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 3 trucks, 23.6ms
# Speed: 1.9ms preprocess, 23.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 11 cars, 3 trucks, 24.0ms
# Speed: 1.1ms preprocess, 24.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 11 cars, 3 trucks, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 10 cars, 2 trucks, 23.8ms
# Speed: 2.1ms preprocess, 23.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 10 cars, 3 trucks, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 10 cars, 3 trucks, 24.6ms
# Speed: 1.1ms preprocess, 24.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 10 cars, 3 trucks, 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 10 cars, 4 trucks, 34.6ms
# Speed: 2.4ms preprocess, 34.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 10 cars, 4 trucks, 24.5ms
# Speed: 1.0ms preprocess, 24.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 cars, 5 trucks, 24.2ms
# Speed: 1.1ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 cars, 5 trucks, 25.1ms
# Speed: 1.5ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 4 trucks, 25.1ms
# Speed: 1.9ms preprocess, 25.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 4 trucks, 25.4ms
# Speed: 2.1ms preprocess, 25.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 4 trucks, 24.6ms
# Speed: 1.7ms preprocess, 24.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 4 trucks, 24.5ms
# Speed: 1.4ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 3 trucks, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 11 cars, 3 trucks, 24.4ms
# Speed: 1.3ms preprocess, 24.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 11 cars, 3 trucks, 24.5ms
# Speed: 1.1ms preprocess, 24.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 11 cars, 3 trucks, 24.7ms
# Speed: 2.1ms preprocess, 24.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 4 trucks, 32.6ms
# Speed: 2.4ms preprocess, 32.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 4 trucks, 24.8ms
# Speed: 1.6ms preprocess, 24.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 25.6ms
# Speed: 2.2ms preprocess, 25.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 3 trucks, 25.5ms
# Speed: 1.3ms preprocess, 25.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 9 cars, 3 trucks, 28.3ms
# Speed: 2.4ms preprocess, 28.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 4 trucks, 25.5ms
# Speed: 1.6ms preprocess, 25.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 4 trucks, 34.3ms
# Speed: 1.3ms preprocess, 34.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 8 cars, 4 trucks, 25.3ms
# Speed: 1.2ms preprocess, 25.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 4 trucks, 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 11 cars, 4 trucks, 26.0ms
# Speed: 3.2ms preprocess, 26.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 10 cars, 3 trucks, 25.3ms
# Speed: 1.6ms preprocess, 25.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 11 cars, 3 trucks, 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons,
4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 12 cars, 2 trucks, 25.8ms
# Speed: 2.6ms preprocess, 25.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 12 cars, 2 trucks, 25.7ms
# Speed: 1.2ms preprocess, 25.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 11 cars, 2 trucks, 25.8ms
# Speed: 1.6ms preprocess, 25.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 11 cars, 2 trucks, 25.9ms
# Speed: 2.0ms preprocess, 25.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 25.7ms
# Speed: 1.4ms preprocess, 25.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 25.9ms
# Speed: 2.3ms preprocess, 25.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 25.9ms
# Speed: 1.1ms preprocess, 25.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 10 cars, 3 trucks, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 9 cars, 4 trucks, 25.7ms
# Speed: 1.1ms preprocess, 25.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 3 trucks, 26.0ms
# Speed: 2.1ms preprocess, 26.0ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 3 trucks, 26.3ms
# Speed: 1.6ms preprocess, 26.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 3 trucks, 26.0ms
# Speed: 1.6ms preprocess, 26.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 3 trucks, 25.9ms
# Speed: 1.3ms preprocess, 25.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 10 cars, 3 trucks, 25.7ms
# Speed: 1.4ms preprocess, 25.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 11 cars, 3 trucks, 25.2ms
# Speed: 1.4ms preprocess, 25.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Processing completed. Output video saved to output_video.mp4
# Response Here's an analysis of the provided image and a table summarizing the findings:
#
# **Analysis:**
#
# The image shows a road scene with several vehicles and pedestrians. The text overlay indicates "ALERT: Accident Detected" and suggests "Medium" severity. However, a direct visual assessment reveals:
#
# *   **Vehicle Damage**: No obvious signs of damage like dents, broken parts, or deployed airbags on any visible vehicles.
# *   **Unusual Vehicle Positions**: All vehicles appear to be within their lanes or designated parking areas. No cars are off-road or at odd angles.
# *   **Debris & Skid Marks**: The road surface looks wet, but there are no visible skid marks, scattered debris, or road obstacles.
# *    two People are walking on the road.
# *   **Traffic Disruption**: Traffic seems to be flowing normally. There are no stopped vehicles blocking the road or apparent congestion.
# *   **Weather Impact**: The road is wet, and the text mentions "Potentially Low Visibility," which could be contributing factors.
#
# **Table:**
#
# | Accident Severity (Details) | Vehicles Involved | Location Type     | Likely Cause                                   |
# | ----------------------------|-------------------|--------------------|------------------------------------------------|
# | Medium (People walking on the road)        | 0 or 1, Unclear     | Merging Roads / T  | Unclear. Potentially Low Visibility and wet floor. |
#
# **Conclusion:**
#
# Based purely on *visible* evidence in the frame, there's no definitive sign of a major accident. The "Medium" alert and "Accident Detected" message are not strongly supported by direct visual observation of damage or disruption. The wet road and potential low visibility are noted as possible contributing factors, and the declared cause remains "Unclear" based on the available visual information. The presence of two individuals walking on the road that are close to cars warrants the "medium" status.
# ✅ Accident detected: Track ID=13, Severity=Accident Severity (Details), Reason=Likely Cause
# ✅ Accident detected: Track ID=13, Severity=Medium (People walking on the road), Reason=Unclear. Potentially Low Visibility and wet floor.
